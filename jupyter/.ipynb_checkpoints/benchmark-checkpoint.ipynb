# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import numpy as np
import pandas as pd
import json
import pathlib
import math

from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, roc_auc_score
from sklearn.metrics import precision_recall_curve, roc_curve

#mpl.rcParams['figure.dpi'] = 300
#sns.set_style("ticks")

sns.set()
sns.set_style('whitegrid')
sns.set_context('paper')
sns.set_palette('Paired', 13)

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# # Config

# %%
dataset_name = 'depth'
kind = 'test'#'test' / 'independent_test'
plot_dir = pathlib.Path('/Users/peter/')
file_format = '.jpg'
savefig_args = {'dpi': 300, 'bbox_inches':'tight'}
two_col_fig_width = 7.5
one_col_fig_width = 3.5

method_mapping = [
    ['observed', 'Observed'],
    ['rf_', 'RF'],
    ['xgb_', 'GBM'],
    ['cnn_', 'conv'],
    ['dcnn_', 'dconv'],
    ['lstm_', 'LSTM'],
    ['blending', 'AllesTM'],
    ['profbval', 'PROFbval'],
    ['spinex', 'SPINE X'],
    ['anglor', 'ANGLOR'],
    ['predyflexy', 'PredyFlexy'],
    ['memsat', 'MEMSAT-SVM'],
    ['polyphobius', 'PolyPhobius']
]

# %% [markdown]
# # Raw data

# %%
conn = sqlite3.connect("../data.db")

# %%
raw_df = pd.read_sql_query(f"select * from raw_data join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) join proteins using (id)", conn)

# %%
raw_df.describe()
# Out:
#               resi      bfactor          phi          psi    acc_chain  \
# count  9119.000000  9119.000000  9119.000000  9119.000000  9119.000000
# mean    204.450707    71.901420    -1.162559    -0.111416     0.323908
# std     155.431013    43.973387     0.672255     1.244709     0.264468
# min       0.000000     5.890000    -3.131487    -3.140995     0.000000
# 25%      76.000000    37.450000    -1.350834    -0.802789     0.072165
# 50%     174.000000    64.410000    -1.144005    -0.646712     0.294416
# 75%     303.000000    99.275000    -1.015406    -0.053161     0.524390
# max     746.000000   260.490000     3.131882     3.141438     1.000000
#
#        acc_complex       tms_nr        re_nr          n_x          n_y  \
# count  9119.000000  9119.000000  9119.000000  9119.000000  9119.000000
# mean      0.251038     1.099463    -0.965128     1.503665     3.428989
# std       0.246289     3.206924     0.284673    18.818497    14.560095
# min       0.000000    -1.000000    -1.000000   -55.810001   -38.498001
# 25%       0.030488    -1.000000    -1.000000   -11.128000    -6.913500
# 50%       0.176471    -1.000000    -1.000000    -0.229000     3.181000
# 75%       0.419118     3.000000    -1.000000    12.770500    13.455000
# max       1.000000    13.000000     3.000000    82.396004    45.527000
#
#           ...               c_x          c_y          c_z       length  \
# count     ...       9119.000000  9119.000000  9119.000000  9119.000000
# mean      ...          1.487327     3.423585    -6.242691   409.901415
# std       ...         18.825496    14.559098    29.080373   174.548703
# min       ...        -55.222000   -37.893002   -95.398003    43.000000
# 25%       ...        -11.177000    -6.926500   -20.815000   268.000000
# 50%       ...         -0.139000     3.160000    -4.927000   417.000000
# 75%       ...         12.946500    13.496500    11.508500   557.000000
# max       ...         80.091003    45.104000    92.435997   747.000000
#
#          thickness   resolution    cov_total  cov_trimmed      num_tms  \
# count  9119.000000  9119.000000  9119.000000       9119.0  9119.000000
# mean     15.412995     2.785175    95.857906        100.0     7.523522
# std       1.228134     0.419614     3.490686          0.0     3.784249
# min      13.600000     1.700000    85.082873        100.0     1.000000
# 25%      14.800000     2.500000    93.142145        100.0     6.000000
# 50%      15.000000     2.800000    95.966387        100.0     7.000000
# 75%      15.700000     3.000000    98.969072        100.0    11.000000
# max      18.400000     3.500000   100.000000        100.0    14.000000
#
#            num_res
# count  9119.000000
# mean      0.717732
# std       1.050149
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       4.000000
#
# [8 rows x 24 columns]

# %%
proteins_df = pd.read_sql_query(f"select * from (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a join proteins using (id)", conn)

# %%
proteins_df.describe()
# Out:
#            length  thickness  resolution   cov_total  cov_trimmed    num_tms  \
# count   31.000000  31.000000   31.000000   31.000000         31.0  31.000000
# mean   294.161290  15.232258    2.727419   95.962736        100.0   5.838710
# std    187.566361   1.101631    0.446094    4.176741          0.0   4.091428
# min     43.000000  13.600000    1.700000   85.082873        100.0   1.000000
# 25%    125.000000  14.750000    2.400000   93.467624        100.0   2.000000
# 50%    268.000000  14.900000    2.800000   96.774194        100.0   6.000000
# 75%    418.500000  15.650000    2.990000  100.000000        100.0   8.500000
# max    747.000000  18.400000    3.500000  100.000000        100.0  14.000000
#
#          num_res
# count  31.000000
# mean    0.548387
# std     0.925156
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     1.000000
# max     4.000000

# %%
sns.distplot(proteins_df.length, kde=False, rug=True, bins=30, label="Reduced data")
#sns.distplot(pd.read_sql_query("select * from proteins", conn).length, kde=True, label="Original data")
plt.legend()
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Benchmark helper functions

# %% [markdown]
# ## Measures

# %%
def exp2name(exp):
    for m, name in method_mapping:
        if exp.lower().startswith(m):
            return name
    return f'MISSING {exp}'

def exp2order(exp):
    for i, (m, name) in enumerate(method_mapping):
        if exp.lower().startswith(m):
            return i
    return f'MISSING {exp}'

# %%
def measures_cont(df, filename=None):
    measures = [pearsonr, mean_absolute_error, mean_squared_error, lambda x, y: math.sqrt(mean_squared_error(x, y))]
    measure_names = ['r', 'MAE', 'MSE', 'RMSE']
    obs = df[df.experiment == "observed"].val_0
    benchmarks = {}
    experiments = df[df.experiment != "observed"].experiment.unique()
    for experiment in sorted(experiments, key=exp2order):
        pred = df[df.experiment == experiment].val_0
        for i, measure in enumerate(measures):
            result = measure(obs, pred)
            if isinstance(result, list) or isinstance(result, tuple):
               
                if not measure_names[i] in benchmarks:
                    benchmarks[measure_names[i]] = []
                benchmarks[measure_names[i]].append(round(result[i], 2))
                #for i in range(len(result)):
                #    if not "{}_{}".format(measure.__name__, i) in benchmarks:
                #        benchmarks["{}_{}".format(measure.__name__, i)] = []
                #    benchmarks["{}_{}".format(measure.__name__, i)].append(round(result[i], 3))
            else:
                if not measure_names[i] in benchmarks:
                    benchmarks[measure_names[i]] = []
                benchmarks[measure_names[i]].append(round(result, 2))
    
    result = pd.DataFrame(benchmarks, index=[exp2name(x) for x in sorted(experiments, key=exp2order)])
    if filename is not None:
        result.to_csv(plot_dir / f'{dataset_name}_{kind}_{filename}.csv')
    return result.style.highlight_min(axis=0, color="yellow").highlight_max(axis=0, color="orange")
    #return pd.DataFrame(benchmarks, index=[exp2name(x) for x in experiments]).sort_values(by="MAE").style.highlight_min(axis=0, color="yellow").highlight_max(axis=0, color="orange")

# %%
def measures_bin(df, filename=None):
    measures = [accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef]
    measure_names = ['ACC', 'P', 'R', 'F1', 'AUC', 'MCC']
    obs = df[df.experiment == "observed"].val_0
    benchmarks = {measure: [] for measure in measure_names}
    experiments = df[df.experiment != "observed"].experiment.unique()
    for experiment in sorted(experiments, key=exp2order):
        pred = df[df.experiment == experiment].val_0.round()
        for i, measure in enumerate(measures):
            benchmarks[measure_names[i]].append(round(measure(obs, pred), 2))
    result = pd.DataFrame(benchmarks, index=[exp2name(x) for x in sorted(experiments, key=exp2order)])
    if filename is not None:
        result.to_csv(plot_dir / f'{dataset_name}_{kind}_{filename}.csv')
    return result.style.highlight_min(axis=0, color="yellow").highlight_max(axis=0, color="orange")
    #return pd.DataFrame(benchmarks, index=[exp2name(x) for x in experiments]).sort_values(by="ACC", ascending=False).style.highlight_min(axis=0, color="yellow").highlight_max(axis=0, color="orange")

# %%
def measures_cat(df, num_classes=3, class_names=None, filename=None):
    if class_names is None:
        class_names = [i for i in range(num_classes)]
        
    measures_all = [accuracy_score]
    measures_class = [precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef]
    measure_all_names = ['ACC']
    measure_names = ['P', 'R', 'F1', 'AUC', 'MCC']
    
    obs = df[df.experiment == "observed"][["val_{}".format(x) for x in range(num_classes)]]
    
    #benchmarks = {measure.__name__: [] for measure in measures_all + measures_class}
    benchmarks = {measure: [] for measure in measure_all_names}
    experiments = df[df.experiment != "observed"].experiment.unique()
    for experiment in sorted(experiments, key=exp2order):
        pred = df[df.experiment == experiment][["val_{}".format(x) for x in range(num_classes)]]
        pred_argmax = np.array(pred).argmax(axis=1)
        for i, measure in enumerate(measures_all):
            benchmarks[measure_all_names[i]].append(round(measure(np.array(obs).argmax(axis=1), pred_argmax), 2))
        
        obs_rounded = np.array(obs)
        pred_rounded = np.zeros(pred.shape)
        for i, argmax in enumerate(pred_argmax):
            pred_rounded[i, argmax] = 1
           
        
            
            #class_results = []
        for i in range(num_classes):
            for m, measure in enumerate(measures_class):
                if not "{} ({})".format(class_names[i], measure_names[m]) in benchmarks:
                    benchmarks["{} ({})".format(class_names[i], measure_names[m])] = []
                benchmarks["{} ({})".format(class_names[i], measure_names[m])].append(round(measure(obs_rounded[:, i], pred_rounded[:, i]), 2))
                #class_results.append(round(measure(obs_rounded[:, i], pred_rounded[:, i]), 3))
            #benchmarks[measure.__name__].append(class_results)
        
    result = pd.DataFrame(benchmarks, index=[exp2name(x) for x in sorted(experiments, key=exp2order)])
    if filename is not None:
        result.to_csv(plot_dir / f'{dataset_name}_{kind}_{filename}.csv')
    return result.style.highlight_min(axis=0, color="yellow").highlight_max(axis=0, color="orange")
    #return pd.DataFrame(benchmarks, index=[exp2name(x) for x in experiments]).sort_values(by="ACC", ascending=False).style.highlight_min(axis=0, color="yellow").highlight_max(axis=0, color="orange")

# %% [markdown]
# <h2>Plots</h2>

# %%
def plots_cont(df, xlab, ylab, filename=None, hist=False, kde=True):
    fig, ax = plt.subplots(1, 1, figsize=(one_col_fig_width, one_col_fig_width))
    #min_val = df.val_0.min()
    #max_val = df.val_0.max()
    #axs[1].set(xlim=(min_val, max_val), ylim=(min_val, max_val))
    for experiment in sorted(df.experiment.unique(), key=exp2order):
        kde_kws = {}
        color = None
        if experiment == "observed":
            #hist = True
            color='black'
            kde_kws["lw"] = 4
        else:
            pass
            #sns.kdeplot(df[df.experiment == 'observed'].val_0, df[df.experiment == experiment].val_0, label=experiment, ax=axs[1])
            #sns.regplot(df[df.experiment == 'observed'].val_0, df[df.experiment == experiment].val_0, label=experiment, ax=axs[1], scatter=False)
        sns.distplot(df[df.experiment == experiment].val_0, label=exp2name(experiment), hist=hist, kde=kde, color=color, ax=ax, kde_kws=kde_kws)
    ax.set(xlabel=xlab, ylabel=ylab)
    ax.legend(frameon=True, facecolor='white', framealpha=0.8)
    #axs[1].set(xlabel='Observed', ylabel='Predicted')
    #axs[1].legend()
    if filename is not None:
        fig.savefig(plot_dir / f'{dataset_name}_{kind}_{filename}.{file_format}', **savefig_args)

# %%
def plots_bin(obs_df, dfs, filename=None):
    fig, ax = plt.subplots(1, 2)
    fig.set_size_inches(two_col_fig_width, two_col_fig_width/2)
    for a in ax:
        a.set_xlim([0, 1])
        a.set_ylim([0, 1])
    
    obs = obs_df[obs_df.experiment == "observed"].val_0
    
    for name, df in dfs.items():
        for experiment in sorted(df[df.experiment != "observed"].experiment.unique(), key=exp2order):
            pr = precision_recall_curve(obs, df[df.experiment == experiment].val_0)
            ax[0].plot(pr[1], pr[0], label=exp2name(experiment))

            roc = roc_curve(obs, df[df.experiment == experiment].val_0)
            ax[1].plot(roc[0], roc[1], label=exp2name(experiment))

    ax[0].set(xlabel="Recall", ylabel="Precision")
    #ax[0].legend()
    ax[1].set(xlabel="FPR or (1 - specificity)", ylabel="TPR or sensitivity")
    ax[1].legend(frameon=True, facecolor='white', framealpha=0.8)
    if filename is not None:
        fig.savefig(plot_dir / f'{dataset_name}_{kind}_{filename}.{file_format}', **savefig_args)

# %%
def plots_cat(obs_df, dfs, num_classes=3, filename=None, class_names=None):
    fig, ax = plt.subplots(num_classes, 2)
    fig.set_size_inches(two_col_fig_width, two_col_fig_width / 2 * num_classes)
    for a in ax:
        for b in a:
            b.set_xlim([0, 1])
            b.set_ylim([0, 1])
            
    if class_names is None:
        class_names = [str(i) for i in range(num_classes)]
    
    obs_rounded = obs_df[obs_df.experiment == "observed"][["val_{}".format(x) for x in range(num_classes)]].values
    
    for name, df in dfs.items():
        for experiment in sorted(df[df.experiment != "observed"].experiment.unique(), key=exp2order):
            pred = df[df.experiment == experiment][["val_{}".format(x) for x in range(num_classes)]]
            pred_argmax = np.array(pred).argmax(axis=1)
            
            pred_rounded = pred.values
            #pred_rounded = np.zeros(pred.shape)
            #for i, argmax in enumerate(pred_argmax):
            #    pred_rounded[i, argmax] = 1
                
            for i in range(num_classes):
                pr = precision_recall_curve(obs_rounded[:, i], pred_rounded[:, i])
                ax[i][0].plot(pr[1], pr[0], label=exp2name(experiment))

                roc = roc_curve(obs_rounded[:, i], pred_rounded[:, i])
                ax[i][1].plot(roc[0], roc[1], label=exp2name(experiment))

                ax[i][0].set(xlabel="Recall", ylabel="Precision")
                ax[i][1].set(xlabel="FPR or (1 - specificity)", ylabel="TPR or sensitivity")
                #ax[i][0].legend()
                if i == 0:
                    ax[i][1].legend(frameon=True, facecolor='white', framealpha=0.8)
                    
                ax[i][0].annotate(class_names[i], (0.1, 0.1), horizontalalignment='center', verticalalignment='center', fontsize='xx-large')
                
    if filename is not None:
        fig.savefig(plot_dir / f'{dataset_name}_{kind}_{filename}.{file_format}', **savefig_args)

# %% [markdown]
# <h1>Bfactors</h1>

# %% [markdown]
# <h2>Bfactors continuous</h2>

# %%
bfactors_cont = pd.read_sql_query(f"select * from mllib_features_continuous_bfactors join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
bfactors_cont.groupby("experiment").describe()
# Out:
#                                    resi                                     \
#                                   count        mean         std  min   25%
# experiment
# blending_bfactors_cont_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0
# cnn_domain_bfactors_IND_TEST     9119.0  204.450707  155.431013  0.0  76.0
# dcnn_domain_bfactors_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0
# lstm_domain_bfactors_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0
# observed                         9119.0  204.450707  155.431013  0.0  76.0
# predyflexy                       9119.0  204.450707  155.431013  0.0  76.0
# profbval_bnorm                   9119.0  204.450707  155.431013  0.0  76.0
# rf_bfactors_cont_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0
# xgb_bfactors_cont_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0
#
#                                                        val_0                \
#                                    50%    75%    max   count          mean
# experiment
# blending_bfactors_cont_IND_TEST  174.0  303.0  746.0  9119.0 -7.735799e-03
# cnn_domain_bfactors_IND_TEST     174.0  303.0  746.0  9119.0 -1.532388e-01
# dcnn_domain_bfactors_IND_TEST    174.0  303.0  746.0  9119.0 -1.282274e-01
# lstm_domain_bfactors_IND_TEST    174.0  303.0  746.0  9119.0 -1.333781e-01
# observed                         174.0  303.0  746.0  9119.0 -2.883000e-17
# predyflexy                       174.0  303.0  746.0  9119.0  1.707874e-01
# profbval_bnorm                   174.0  303.0  746.0  9119.0  1.206163e-02
# rf_bfactors_cont_IND_TEST        174.0  303.0  746.0  9119.0  2.086844e-02
# xgb_bfactors_cont_IND_TEST       174.0  303.0  746.0  9119.0 -2.955301e-03
#
#                                                                          \
#                                       std       min       25%       50%
# experiment
# blending_bfactors_cont_IND_TEST  0.479217 -0.759318 -0.376634 -0.133195
# cnn_domain_bfactors_IND_TEST     0.433567 -0.868519 -0.467451 -0.268236
# dcnn_domain_bfactors_IND_TEST    0.465115 -0.865347 -0.484678 -0.251793
# lstm_domain_bfactors_IND_TEST    0.418023 -0.804733 -0.454426 -0.245034
# observed                         1.000055 -2.373485 -0.682823 -0.213858
# predyflexy                       0.415221 -0.696000 -0.185000  0.120000
# profbval_bnorm                   0.876200 -2.530000 -0.670000 -0.100000
# rf_bfactors_cont_IND_TEST        0.399447 -0.675185 -0.320166 -0.058063
# xgb_bfactors_cont_IND_TEST       0.448392 -0.774225 -0.360835 -0.095736
#
#
#                                       75%        max
# experiment
# blending_bfactors_cont_IND_TEST  0.261611   2.316440
# cnn_domain_bfactors_IND_TEST     0.050474   2.124419
# dcnn_domain_bfactors_IND_TEST    0.127177   1.892927
# lstm_domain_bfactors_IND_TEST    0.109749   1.958333
# observed                         0.433227  11.068478
# predyflexy                       0.504000   1.521000
# profbval_bnorm                   0.600000   4.750000
# rf_bfactors_cont_IND_TEST        0.299977   2.050862
# xgb_bfactors_cont_IND_TEST       0.281561   2.442103

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(bfactors_cont, filename='bfactors_cont')
# Out:
# <style  type="text/css" >
#     #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row6_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col3 {
#             : ;
#             background-color:  orange;
#         }</style>
# <table id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row0_col0" class="data row0 col0" >0.44</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row0_col1" class="data row0 col1" >0.67</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row0_col2" class="data row0 col2" >0.81</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row0_col3" class="data row0 col3" >0.9</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row1_col0" class="data row1 col0" >0.47</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row1_col1" class="data row1 col1" >0.65</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row1_col2" class="data row1 col2" >0.78</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row1_col3" class="data row1 col3" >0.89</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row2_col0" class="data row2 col0" >0.5</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row2_col1" class="data row2 col1" >0.63</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row2_col2" class="data row2 col2" >0.78</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row2_col3" class="data row2 col3" >0.88</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row3_col0" class="data row3 col0" >0.5</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row3_col1" class="data row3 col1" >0.63</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row3_col2" class="data row3 col2" >0.77</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row3_col3" class="data row3 col3" >0.88</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row4_col0" class="data row4 col0" >0.5</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row4_col1" class="data row4 col1" >0.63</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row4_col2" class="data row4 col2" >0.78</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row4_col3" class="data row4 col3" >0.88</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col0" class="data row5 col0" >0.51</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col1" class="data row5 col1" >0.63</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col2" class="data row5 col2" >0.75</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row5_col3" class="data row5 col3" >0.86</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row6" class="row_heading level0 row6" >PROFbval</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row6_col0" class="data row6 col0" >0.4</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row6_col1" class="data row6 col1" >0.78</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row6_col2" class="data row6 col2" >1.07</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row6_col3" class="data row6 col3" >1.04</td>
#     </tr>    <tr>
#         <th id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3level0_row7" class="row_heading level0 row7" >PredyFlexy</th>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col0" class="data row7 col0" >0.13</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col1" class="data row7 col1" >0.8</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col2" class="data row7 col2" >1.09</td>
#         <td id="T_cbbc77b0_9fdd_11e9_875b_a45e60b969a3row7_col3" class="data row7 col3" >1.04</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(bfactors_cont, "Normalized B-factors", "Density", filename='bfactors_cont')

fig, ax = plt.subplots()
#fig.set_size_inches(11.7, 8.27)
sns.distplot(raw_df.bfactor, ax=ax)
ax.set(xlabel="Raw B-factors", ylabel="Density")
ax.legend()
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# No handles with labels found to put in legend.

# %% [markdown]
# <h2>Bfactors binary</h2>

# %%
bfactors_bin = pd.read_sql_query(f"select * from mllib_features_binary_bfactors join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
bfactors_bin.groupby("experiment").describe()
# Out:
#                                   resi                                     \
#                                  count        mean         std  min   25%
# experiment
# blending_bfactors_bin_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0
# cnn_domain_bfactors_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0
# dcnn_domain_bfactors_IND_TEST   9119.0  204.450707  155.431013  0.0  76.0
# lstm_domain_bfactors_IND_TEST   9119.0  204.450707  155.431013  0.0  76.0
# observed                        9119.0  204.450707  155.431013  0.0  76.0
# profbval_strict                 9119.0  204.450707  155.431013  0.0  76.0
# rf_bfactors_bin_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0
# xgb_bfactors_bin_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0
#
#                                                       val_0            \
#                                   50%    75%    max   count      mean
# experiment
# blending_bfactors_bin_IND_TEST  174.0  303.0  746.0  9119.0  0.393814
# cnn_domain_bfactors_IND_TEST    174.0  303.0  746.0  9119.0  0.386951
# dcnn_domain_bfactors_IND_TEST   174.0  303.0  746.0  9119.0  0.397690
# lstm_domain_bfactors_IND_TEST   174.0  303.0  746.0  9119.0  0.383937
# observed                        174.0  303.0  746.0  9119.0  0.383595
# profbval_strict                 174.0  303.0  746.0  9119.0  0.107249
# rf_bfactors_bin_IND_TEST        174.0  303.0  746.0  9119.0  0.397103
# xgb_bfactors_bin_IND_TEST       174.0  303.0  746.0  9119.0  0.370638
#
#                                                                         \
#                                      std       min       25%       50%
# experiment
# blending_bfactors_bin_IND_TEST  0.190914  0.133883  0.226693  0.345966
# cnn_domain_bfactors_IND_TEST    0.190750  0.067226  0.228611  0.350454
# dcnn_domain_bfactors_IND_TEST   0.213568  0.067157  0.212335  0.349745
# lstm_domain_bfactors_IND_TEST   0.198819  0.059241  0.213028  0.350469
# observed                        0.486288  0.000000  0.000000  0.000000
# profbval_strict                 0.309446  0.000000  0.000000  0.000000
# rf_bfactors_bin_IND_TEST        0.164196  0.100980  0.257156  0.381966
# xgb_bfactors_bin_IND_TEST       0.214125  0.038722  0.186186  0.326661
#
#
#                                      75%       max
# experiment
# blending_bfactors_bin_IND_TEST  0.541193  0.874062
# cnn_domain_bfactors_IND_TEST    0.519032  0.939388
# dcnn_domain_bfactors_IND_TEST   0.559743  0.944179
# lstm_domain_bfactors_IND_TEST   0.536434  0.928270
# observed                        1.000000  1.000000
# profbval_strict                 0.000000  1.000000
# rf_bfactors_bin_IND_TEST        0.519963  0.894289
# xgb_bfactors_bin_IND_TEST       0.534911  0.947724

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_bin(bfactors_bin, filename='bfactors_bin')
# Out:
# <style  type="text/css" >
#     #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col5 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ACC</th>
#         <th class="col_heading level0 col1" >P</th>
#         <th class="col_heading level0 col2" >R</th>
#         <th class="col_heading level0 col3" >F1</th>
#         <th class="col_heading level0 col4" >AUC</th>
#         <th class="col_heading level0 col5" >MCC</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col0" class="data row0 col0" >0.68</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col1" class="data row0 col1" >0.62</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col2" class="data row0 col2" >0.46</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col3" class="data row0 col3" >0.53</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col4" class="data row0 col4" >0.64</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row0_col5" class="data row0 col5" >0.31</td>
#     </tr>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row1_col0" class="data row1 col0" >0.69</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row1_col1" class="data row1 col1" >0.63</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row1_col2" class="data row1 col2" >0.47</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row1_col3" class="data row1 col3" >0.54</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row1_col4" class="data row1 col4" >0.65</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row1_col5" class="data row1 col5" >0.32</td>
#     </tr>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col0" class="data row2 col0" >0.7</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col1" class="data row2 col1" >0.65</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col2" class="data row2 col2" >0.46</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col3" class="data row2 col3" >0.54</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col4" class="data row2 col4" >0.65</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row2_col5" class="data row2 col5" >0.34</td>
#     </tr>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col0" class="data row3 col0" >0.7</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col1" class="data row3 col1" >0.63</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col2" class="data row3 col2" >0.52</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col3" class="data row3 col3" >0.57</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col4" class="data row3 col4" >0.66</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row3_col5" class="data row3 col5" >0.34</td>
#     </tr>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col0" class="data row4 col0" >0.7</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col1" class="data row4 col1" >0.64</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col2" class="data row4 col2" >0.48</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col3" class="data row4 col3" >0.55</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col4" class="data row4 col4" >0.66</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row4_col5" class="data row4 col5" >0.33</td>
#     </tr>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col0" class="data row5 col0" >0.7</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col1" class="data row5 col1" >0.64</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col2" class="data row5 col2" >0.49</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col3" class="data row5 col3" >0.56</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col4" class="data row5 col4" >0.66</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row5_col5" class="data row5 col5" >0.34</td>
#     </tr>    <tr>
#         <th id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3level0_row6" class="row_heading level0 row6" >PROFbval</th>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col0" class="data row6 col0" >0.65</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col1" class="data row6 col1" >0.66</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col2" class="data row6 col2" >0.19</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col3" class="data row6 col3" >0.29</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col4" class="data row6 col4" >0.56</td>
#         <td id="T_cced871e_9fdd_11e9_81cf_a45e60b969a3row6_col5" class="data row6 col5" >0.2</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark curves</h3>

# %%
plots_bin(bfactors_bin, {"bin": bfactors_bin}, filename='bfactors_bin')

# %% [markdown]
# # Bfactors - TMS

# %% [markdown]
# <h2>Bfactors continuous</h2>

# %%
bfactors_cont_tms = pd.read_sql_query(f"select p.experiment, p.id, p.resi, p.val_0 from mllib_features_continuous_bfactors as p join raw_data using (id, resi) join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where topo='T' and experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
bfactors_cont_tms.groupby("experiment").describe()
# Out:
#                                    resi                                      \
#                                   count        mean         std  min    25%
# experiment
# blending_bfactors_cont_IND_TEST  4010.0  170.450125  132.154549  0.0  61.25
# cnn_domain_bfactors_IND_TEST     4010.0  170.450125  132.154549  0.0  61.25
# dcnn_domain_bfactors_IND_TEST    4010.0  170.450125  132.154549  0.0  61.25
# lstm_domain_bfactors_IND_TEST    4010.0  170.450125  132.154549  0.0  61.25
# observed                         4010.0  170.450125  132.154549  0.0  61.25
# predyflexy                       4010.0  170.450125  132.154549  0.0  61.25
# profbval_bnorm                   4010.0  170.450125  132.154549  0.0  61.25
# rf_bfactors_cont_IND_TEST        4010.0  170.450125  132.154549  0.0  61.25
# xgb_bfactors_cont_IND_TEST       4010.0  170.450125  132.154549  0.0  61.25
#
#                                                        val_0            \
#                                    50%    75%    max   count      mean
# experiment
# blending_bfactors_cont_IND_TEST  139.0  266.0  557.0  4010.0 -0.232748
# cnn_domain_bfactors_IND_TEST     139.0  266.0  557.0  4010.0 -0.329972
# dcnn_domain_bfactors_IND_TEST    139.0  266.0  557.0  4010.0 -0.351357
# lstm_domain_bfactors_IND_TEST    139.0  266.0  557.0  4010.0 -0.323596
# observed                         139.0  266.0  557.0  4010.0 -0.251624
# predyflexy                       139.0  266.0  557.0  4010.0  0.042768
# profbval_bnorm                   139.0  266.0  557.0  4010.0 -0.604633
# rf_bfactors_cont_IND_TEST        139.0  266.0  557.0  4010.0 -0.240455
# xgb_bfactors_cont_IND_TEST       139.0  266.0  557.0  4010.0 -0.263100
#
#                                                                          \
#                                       std       min       25%       50%
# experiment
# blending_bfactors_cont_IND_TEST  0.318806 -0.744997 -0.447721 -0.315988
# cnn_domain_bfactors_IND_TEST     0.294295 -0.868519 -0.520142 -0.407451
# dcnn_domain_bfactors_IND_TEST    0.304113 -0.865347 -0.556021 -0.428061
# lstm_domain_bfactors_IND_TEST    0.279914 -0.800477 -0.512504 -0.399880
# observed                         0.751957 -2.373485 -0.758404 -0.372057
# predyflexy                       0.393973 -0.651000 -0.317000 -0.044500
# profbval_bnorm                   0.540517 -2.530000 -0.930000 -0.680000
# rf_bfactors_cont_IND_TEST        0.246622 -0.675185 -0.396383 -0.316965
# xgb_bfactors_cont_IND_TEST       0.289028 -0.761144 -0.451076 -0.337828
#
#
#                                       75%       max
# experiment
# blending_bfactors_cont_IND_TEST -0.110488  1.879405
# cnn_domain_bfactors_IND_TEST    -0.216365  1.723061
# dcnn_domain_bfactors_IND_TEST   -0.235513  1.501179
# lstm_domain_bfactors_IND_TEST   -0.215755  1.623132
# observed                         0.090656  4.600515
# predyflexy                       0.339000  1.494000
# profbval_bnorm                  -0.350000  4.590000
# rf_bfactors_cont_IND_TEST       -0.159421  1.913024
# xgb_bfactors_cont_IND_TEST      -0.152505  2.272868

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(bfactors_cont_tms, filename='bfactors_cont_tms')
# Out:
# <style  type="text/css" >
#     #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row3_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row6_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row6_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row7_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row7_col1 {
#             : ;
#             background-color:  orange;
#         }</style>
# <table id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row0_col0" class="data row0 col0" >0.3</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row0_col1" class="data row0 col1" >0.53</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row0_col2" class="data row0 col2" >0.51</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row0_col3" class="data row0 col3" >0.72</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row1_col0" class="data row1 col0" >0.32</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row1_col1" class="data row1 col1" >0.52</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row1_col2" class="data row1 col2" >0.51</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row1_col3" class="data row1 col3" >0.71</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row2_col0" class="data row2 col0" >0.36</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row2_col1" class="data row2 col1" >0.51</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row2_col2" class="data row2 col2" >0.5</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row2_col3" class="data row2 col3" >0.71</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row3_col0" class="data row3 col0" >0.37</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row3_col1" class="data row3 col1" >0.51</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row3_col2" class="data row3 col2" >0.5</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row3_col3" class="data row3 col3" >0.71</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row4_col0" class="data row4 col0" >0.36</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row4_col1" class="data row4 col1" >0.51</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row4_col2" class="data row4 col2" >0.5</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row4_col3" class="data row4 col3" >0.71</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col0" class="data row5 col0" >0.37</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col1" class="data row5 col1" >0.52</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col2" class="data row5 col2" >0.49</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row5_col3" class="data row5 col3" >0.7</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row6" class="row_heading level0 row6" >PROFbval</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row6_col0" class="data row6 col0" >0.12</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row6_col1" class="data row6 col1" >0.66</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row6_col2" class="data row6 col2" >0.88</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row6_col3" class="data row6 col3" >0.94</td>
#     </tr>    <tr>
#         <th id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3level0_row7" class="row_heading level0 row7" >PredyFlexy</th>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row7_col0" class="data row7 col0" >0.01</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row7_col1" class="data row7 col1" >0.7</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row7_col2" class="data row7 col2" >0.8</td>
#         <td id="T_ce33c002_9fdd_11e9_bbbf_a45e60b969a3row7_col3" class="data row7 col3" >0.9</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(bfactors_cont_tms, "Normalized B-factors", "Density", filename='bfactors_cont_tms')

fig, ax = plt.subplots()
#fig.set_size_inches(11.7, 8.27)
sns.distplot(raw_df.bfactor, ax=ax)
ax.set(xlabel="Raw Bfactors", ylabel="Density")
ax.legend()
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# No handles with labels found to put in legend.

# %% [markdown]
# <h2>Bfactors binary</h2>

# %%
bfactors_bin_tms = pd.read_sql_query(f"select p.experiment, p.id, p.resi, p.val_0 from mllib_features_binary_bfactors as p join raw_data using (id, resi) join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where topo='T' and experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
bfactors_bin_tms.groupby("experiment").describe()
# Out:
#                                   resi                                      \
#                                  count        mean         std  min    25%
# experiment
# blending_bfactors_bin_IND_TEST  4010.0  170.450125  132.154549  0.0  61.25
# cnn_domain_bfactors_IND_TEST    4010.0  170.450125  132.154549  0.0  61.25
# dcnn_domain_bfactors_IND_TEST   4010.0  170.450125  132.154549  0.0  61.25
# lstm_domain_bfactors_IND_TEST   4010.0  170.450125  132.154549  0.0  61.25
# observed                        4010.0  170.450125  132.154549  0.0  61.25
# profbval_strict                 4010.0  170.450125  132.154549  0.0  61.25
# rf_bfactors_bin_IND_TEST        4010.0  170.450125  132.154549  0.0  61.25
# xgb_bfactors_bin_IND_TEST       4010.0  170.450125  132.154549  0.0  61.25
#
#                                                       val_0            \
#                                   50%    75%    max   count      mean
# experiment
# blending_bfactors_bin_IND_TEST  139.0  266.0  557.0  4010.0  0.298158
# cnn_domain_bfactors_IND_TEST    139.0  266.0  557.0  4010.0  0.297942
# dcnn_domain_bfactors_IND_TEST   139.0  266.0  557.0  4010.0  0.285640
# lstm_domain_bfactors_IND_TEST   139.0  266.0  557.0  4010.0  0.287767
# observed                        139.0  266.0  557.0  4010.0  0.276808
# profbval_strict                 139.0  266.0  557.0  4010.0  0.003990
# rf_bfactors_bin_IND_TEST        139.0  266.0  557.0  4010.0  0.281339
# xgb_bfactors_bin_IND_TEST       139.0  266.0  557.0  4010.0  0.248596
#
#                                                                         \
#                                      std       min       25%       50%
# experiment
# blending_bfactors_bin_IND_TEST  0.139901  0.136756  0.196518  0.248747
# cnn_domain_bfactors_IND_TEST    0.145510  0.067226  0.192200  0.256053
# dcnn_domain_bfactors_IND_TEST   0.154632  0.078292  0.173005  0.238975
# lstm_domain_bfactors_IND_TEST   0.152315  0.059241  0.173307  0.244956
# observed                        0.447477  0.000000  0.000000  0.000000
# profbval_strict                 0.063048  0.000000  0.000000  0.000000
# rf_bfactors_bin_IND_TEST        0.111949  0.100980  0.201602  0.255528
# xgb_bfactors_bin_IND_TEST       0.150090  0.041006  0.140574  0.205212
#
#
#                                      75%       max
# experiment
# blending_bfactors_bin_IND_TEST  0.357206  0.838584
# cnn_domain_bfactors_IND_TEST    0.370707  0.903294
# dcnn_domain_bfactors_IND_TEST   0.355563  0.889444
# lstm_domain_bfactors_IND_TEST   0.368073  0.871449
# observed                        1.000000  1.000000
# profbval_strict                 0.000000  1.000000
# rf_bfactors_bin_IND_TEST        0.334572  0.841996
# xgb_bfactors_bin_IND_TEST       0.316704  0.945988

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_bin(bfactors_bin_tms, filename='bfactors_bin_tms')
# Out:
# <style  type="text/css" >
#     #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row6_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row6_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row6_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row6_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row6_col5 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ACC</th>
#         <th class="col_heading level0 col1" >P</th>
#         <th class="col_heading level0 col2" >R</th>
#         <th class="col_heading level0 col3" >F1</th>
#         <th class="col_heading level0 col4" >AUC</th>
#         <th class="col_heading level0 col5" >MCC</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col0" class="data row0 col0" >0.73</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col1" class="data row0 col1" >0.58</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col2" class="data row0 col2" >0.12</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col3" class="data row0 col3" >0.19</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col4" class="data row0 col4" >0.54</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row0_col5" class="data row0 col5" >0.17</td>
#     </tr>    <tr>
#         <th id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col0" class="data row1 col0" >0.73</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col1" class="data row1 col1" >0.55</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col2" class="data row1 col2" >0.17</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col3" class="data row1 col3" >0.26</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col4" class="data row1 col4" >0.56</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row1_col5" class="data row1 col5" >0.18</td>
#     </tr>    <tr>
#         <th id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col0" class="data row2 col0" >0.73</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col1" class="data row2 col1" >0.56</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col2" class="data row2 col2" >0.2</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col3" class="data row2 col3" >0.3</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col4" class="data row2 col4" >0.57</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row2_col5" class="data row2 col5" >0.21</td>
#     </tr>    <tr>
#         <th id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col0" class="data row3 col0" >0.73</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col1" class="data row3 col1" >0.54</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col2" class="data row3 col2" >0.22</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col3" class="data row3 col3" >0.31</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col4" class="data row3 col4" >0.57</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row3_col5" class="data row3 col5" >0.21</td>
#     </tr>    <tr>
#         <th id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col0" class="data row4 col0" >0.73</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col1" class="data row4 col1" >0.54</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col2" class="data row4 col2" >0.22</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col3" class="data row4 col3" >0.31</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col4" class="data row4 col4" >0.57</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row4_col5" class="data row4 col5" >0.21</td>
#     </tr>    <tr>
#         <th id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col0" class="data row5 col0" >0.73</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col1" class="data row5 col1" >0.55</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col2" class="data row5 col2" >0.22</td>
#         <td id="T_cf5f5892_9fdd_11e9_ab50_a45e60b969a3row5_col3" class="data row5 col3" >0.31</td>

# %% [markdown]
# <h3>Benchmark curves</h3>

# %%
plots_bin(bfactors_bin_tms, {"bin": bfactors_bin_tms}, filename='bfactors_bin_tms')

# %% [markdown]
# <h1>Z-coordinates</h1>

# %% [markdown]
# <h2>Z-coordinates continuous</h2>

# %%
zcoords_cont = pd.read_sql_query(f"select * from mllib_features_continuous_ZCoordinates join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
zcoords_cont.groupby("experiment").describe()
# Out:
#                                   resi                                     \
#                                  count        mean         std  min   25%
# experiment
# blending_zcoords_cont_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0
# cnn_domain_zcoords_IND_TEST     9119.0  204.450707  155.431013  0.0  76.0
# dcnn_domain_zcoords_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0
# lstm_domain_zcoords_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0
# observed                        9119.0  204.450707  155.431013  0.0  76.0
# rf_zcoords_cont_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0
# xgb_zcoords_cont_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0
#
#                                                       val_0            \
#                                   50%    75%    max   count      mean
# experiment
# blending_zcoords_cont_IND_TEST  174.0  303.0  746.0  9119.0 -3.411381
# cnn_domain_zcoords_IND_TEST     174.0  303.0  746.0  9119.0 -2.615882
# dcnn_domain_zcoords_IND_TEST    174.0  303.0  746.0  9119.0 -3.118907
# lstm_domain_zcoords_IND_TEST    174.0  303.0  746.0  9119.0 -3.556133
# observed                        174.0  303.0  746.0  9119.0 -3.528431
# rf_zcoords_cont_IND_TEST        174.0  303.0  746.0  9119.0 -2.436911
# xgb_zcoords_cont_IND_TEST       174.0  303.0  746.0  9119.0 -2.181585
#
#                                                                            \
#                                       std        min        25%       50%
# experiment
# blending_zcoords_cont_IND_TEST  15.312767 -25.161315 -18.497631 -3.957815
# cnn_domain_zcoords_IND_TEST     14.438066 -25.000000 -15.856489 -2.223068
# dcnn_domain_zcoords_IND_TEST    14.401329 -25.000000 -16.723899 -3.595061
# lstm_domain_zcoords_IND_TEST    15.321014 -24.603902 -18.669107 -4.000594
# observed                        17.203373 -25.000000 -20.734500 -4.707000
# rf_zcoords_cont_IND_TEST         8.855791 -24.068673  -8.600317 -2.093967
# xgb_zcoords_cont_IND_TEST       10.457654 -23.873554 -10.650663 -2.007844
#
#
#                                       75%        max
# experiment
# blending_zcoords_cont_IND_TEST  10.099669  25.362895
# cnn_domain_zcoords_IND_TEST      9.391068  24.669275
# dcnn_domain_zcoords_IND_TEST     9.354854  25.000000
# lstm_domain_zcoords_IND_TEST     9.847726  24.772790
# observed                        11.403500  25.000000
# rf_zcoords_cont_IND_TEST         2.990508  22.272620
# xgb_zcoords_cont_IND_TEST        4.756929  24.044033

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(zcoords_cont, filename='zcoords_cont')
# Out:
# <style  type="text/css" >
#     #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row4_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col0" class="data row0 col0" >0.79</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col1" class="data row0 col1" >9.1</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col2" class="data row0 col2" >134.69</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row0_col3" class="data row0 col3" >11.61</td>
#     </tr>    <tr>
#         <th id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row1_col0" class="data row1 col0" >0.84</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row1_col1" class="data row1 col1" >7.82</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row1_col2" class="data row1 col2" >106.05</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row1_col3" class="data row1 col3" >10.3</td>
#     </tr>    <tr>
#         <th id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row2_col0" class="data row2 col0" >0.87</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row2_col1" class="data row2 col1" >5.18</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row2_col2" class="data row2 col2" >71.3</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row2_col3" class="data row2 col3" >8.44</td>
#     </tr>    <tr>
#         <th id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row3_col0" class="data row3 col0" >0.92</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row3_col1" class="data row3 col1" >4.45</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row3_col2" class="data row3 col2" >47.96</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row3_col3" class="data row3 col3" >6.93</td>
#     </tr>    <tr>
#         <th id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row4_col0" class="data row4 col0" >0.93</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row4_col1" class="data row4 col1" >3.71</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row4_col2" class="data row4 col2" >40.84</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row4_col3" class="data row4 col3" >6.39</td>
#     </tr>    <tr>
#         <th id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col0" class="data row5 col0" >0.93</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col1" class="data row5 col1" >3.72</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col2" class="data row5 col2" >39.96</td>
#         <td id="T_d062542e_9fdd_11e9_8daa_a45e60b969a3row5_col3" class="data row5 col3" >6.32</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(zcoords_cont, "Z-coordinate", "Density", filename='zcoords_cont')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plots_cont(zcoords_cont, "Z-coordinate", "Density", filename='hist_zcoords_cont', hist=True, kde=False)
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Topology

# %%
zcoords_cat = pd.read_sql_query(f"select * from mllib_features_categorical_Topology join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
zcoords_cat.groupby("experiment").describe()
# Out:
#                                 resi                                     \
#                                count        mean         std  min   25%
# experiment
# blending_topo_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0
# cnn_domain_zcoords_IND_TEST   9119.0  204.450707  155.431013  0.0  76.0
# dcnn_domain_zcoords_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0
# lstm_domain_zcoords_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0
# memsat_svm                    9119.0  204.450707  155.431013  0.0  76.0
# observed                      9119.0  204.450707  155.431013  0.0  76.0
# polyphobius                   9119.0  204.450707  155.431013  0.0  76.0
# rf_topo_IND_TEST              9119.0  204.450707  155.431013  0.0  76.0
# xgb_topo_IND_TEST             9119.0  204.450707  155.431013  0.0  76.0
#
#                                                     val_0              ...     \
#                                 50%    75%    max   count      mean    ...
# experiment                                                             ...
# blending_topo_IND_TEST        174.0  303.0  746.0  9119.0  0.335855    ...
# cnn_domain_zcoords_IND_TEST   174.0  303.0  746.0  9119.0  0.319371    ...
# dcnn_domain_zcoords_IND_TEST  174.0  303.0  746.0  9119.0  0.324100    ...
# lstm_domain_zcoords_IND_TEST  174.0  303.0  746.0  9119.0  0.339443    ...
# memsat_svm                    174.0  303.0  746.0  9119.0  0.369997    ...
# observed                      174.0  303.0  746.0  9119.0  0.343568    ...
# polyphobius                   174.0  303.0  746.0  9119.0  0.302884    ...
# rf_topo_IND_TEST              174.0  303.0  746.0  9119.0  0.322587    ...
# xgb_topo_IND_TEST             174.0  303.0  746.0  9119.0  0.335318    ...
#
#                                  val_2             val_3                      \
#                                    75%       max   count      mean       std
# experiment
# blending_topo_IND_TEST        0.167226  0.968358  9119.0  0.031637  0.063047
# cnn_domain_zcoords_IND_TEST   0.345495  0.985136  9119.0  0.021545  0.027422
# dcnn_domain_zcoords_IND_TEST  0.296829  0.988478  9119.0  0.025007  0.045414
# lstm_domain_zcoords_IND_TEST  0.208575  0.993956  9119.0  0.027842  0.057174
# memsat_svm                    0.000000  1.000000  9119.0  0.003948  0.062711
# observed                      0.000000  1.000000  9119.0  0.019739  0.139110
# polyphobius                   1.000000  1.000000  9119.0  0.000000  0.000000
# rf_topo_IND_TEST              0.307000  0.880536  9119.0  0.029228  0.025522
# xgb_topo_IND_TEST             0.236423  0.993539  9119.0  0.014102  0.022381
#
#
#                                    min       25%       50%       75%       max
# experiment
# blending_topo_IND_TEST        0.006444  0.013387  0.018692  0.023086  0.738655
# cnn_domain_zcoords_IND_TEST   0.000069  0.004327  0.011844  0.028010  0.235160
# dcnn_domain_zcoords_IND_TEST  0.000268  0.003984  0.010306  0.027685  0.514985
# lstm_domain_zcoords_IND_TEST  0.000780  0.006055  0.011467  0.023664  0.572984
# memsat_svm                    0.000000  0.000000  0.000000  0.000000  1.000000
# observed                      0.000000  0.000000  0.000000  0.000000  1.000000
# polyphobius                   0.000000  0.000000  0.000000  0.000000  0.000000
# rf_topo_IND_TEST              0.000000  0.013839  0.022679  0.035714  0.249321
# xgb_topo_IND_TEST             0.000935  0.004092  0.007673  0.015002  0.419998
#
# [9 rows x 40 columns]

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cat(zcoords_cat, 4, class_names=['In', 'TMS', 'Out', 'RER'], filename='zcoords_cat')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# <style  type="text/css" >
#     #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row0_col6 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row0_col16 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row0_col17 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row0_col18 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row0_col19 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row0_col20 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row1_col16 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row2_col16 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row2_col17 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row2_col18 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row2_col19 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row2_col20 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row3_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row3_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row3_col10 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row3_col12 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row3_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row4_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row4_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row4_col8 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row4_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row4_col10 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row4_col11 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col8 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col10 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col11 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col12 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col13 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col17 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col18 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col19 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row5_col20 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col5 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col6 {
#             : ;
#             background-color:  orange;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col7 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col11 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col12 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col13 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col14 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row6_col15 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col8 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col9 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col10 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col16 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col17 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col18 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col19 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3row7_col20 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_d2533a3a_9fdd_11e9_8ec0_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ACC</th>
#         <th class="col_heading level0 col1" >In (P)</th>
#         <th class="col_heading level0 col2" >In (R)</th>
#         <th class="col_heading level0 col3" >In (F1)</th>
#         <th class="col_heading level0 col4" >In (AUC)</th>
#         <th class="col_head

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
 plots_cat(zcoords_cat, {"cat": zcoords_cat}, num_classes=4, filename='zcoords_cat', class_names=['In', 'TMS', 'Out', 'RER'])

# %% [markdown]
# <h1>Phi angles</h2>

# %% [markdown]
# <h2>Phi angles continuous</h2>

# %%
phi_cont = pd.read_sql_query(f"select * from mllib_features_continuous_PhiAngles join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
phi_cont.groupby("experiment").describe()
# Out:
#                                resi                                            \
#                               count        mean         std  min   25%    50%
# experiment
# anglor_phi                   9119.0  204.450707  155.431013  0.0  76.0  174.0
# blending_phi_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0  174.0
# cnn_domain_angles_IND_TEST   9119.0  204.450707  155.431013  0.0  76.0  174.0
# dcnn_domain_angles_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# lstm_domain_angles_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# observed                     9119.0  204.450707  155.431013  0.0  76.0  174.0
# rf_phi_IND_TEST              9119.0  204.450707  155.431013  0.0  76.0  174.0
# spinex_phi                   9119.0  204.450707  155.431013  0.0  76.0  174.0
# xgb_phi_IND_TEST             9119.0  204.450707  155.431013  0.0  76.0  174.0
#
#                                             val_0                        \
#                                75%    max   count       mean        std
# experiment
# anglor_phi                   303.0  746.0  9119.0 -66.661465  25.479493
# blending_phi_IND_TEST        303.0  746.0  9119.0 -67.886652  22.645479
# cnn_domain_angles_IND_TEST   303.0  746.0  9119.0 -67.197750  23.577925
# dcnn_domain_angles_IND_TEST  303.0  746.0  9119.0 -66.695544  23.438048
# lstm_domain_angles_IND_TEST  303.0  746.0  9119.0 -66.765858  24.798872
# observed                     303.0  746.0  9119.0 -66.609733  38.517392
# rf_phi_IND_TEST              303.0  746.0  9119.0 -67.987223  19.401911
# spinex_phi                   303.0  746.0  9119.0 -70.252988  31.772793
# xgb_phi_IND_TEST             303.0  746.0  9119.0 -67.370598  19.901514
#
#                                                                           \
#                                     min        25%        50%        75%
# experiment
# anglor_phi                  -114.000000 -74.500000 -65.000000 -62.500000
# blending_phi_IND_TEST       -126.144796 -76.039278 -67.039128 -63.859223
# cnn_domain_angles_IND_TEST  -139.632162 -75.014351 -65.005619 -62.471070
# dcnn_domain_angles_IND_TEST -137.505608 -72.834067 -64.365758 -62.869994
# lstm_domain_angles_IND_TEST -126.162986 -73.649045 -64.713433 -63.253777
# observed                    -179.421007 -77.397074 -65.546640 -58.178465
# rf_phi_IND_TEST             -114.125389 -76.239697 -69.521703 -65.096164
# spinex_phi                  -138.400000 -85.200000 -67.600000 -63.900000
# xgb_phi_IND_TEST            -120.471315 -75.927301 -68.040755 -63.371491
#
#
#                                     max
# experiment
# anglor_phi                   180.000000
# blending_phi_IND_TEST         93.674453
# cnn_domain_angles_IND_TEST   104.100920
# dcnn_domain_angles_IND_TEST  107.380486
# lstm_domain_angles_IND_TEST  100.839468
# observed                     179.443630
# rf_phi_IND_TEST               68.533972
# spinex_phi                    98.800000
# xgb_phi_IND_TEST              81.401769

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(phi_cont, filename='phi_cont')
# Out:
# <style  type="text/css" >
#     #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row2_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row7_col0 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row0_col0" class="data row0 col0" >0.55</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row0_col1" class="data row0 col1" >18.91</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row0_col2" class="data row0 col2" >1039.18</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row0_col3" class="data row0 col3" >32.24</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row1_col0" class="data row1 col0" >0.57</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row1_col1" class="data row1 col1" >18.5</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row1_col2" class="data row1 col2" >1012.28</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row1_col3" class="data row1 col3" >31.82</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row2_col0" class="data row2 col0" >0.59</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row2_col1" class="data row2 col1" >16.93</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row2_col2" class="data row2 col2" >970.28</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row2_col3" class="data row2 col3" >31.15</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row3_col0" class="data row3 col0" >0.56</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row3_col1" class="data row3 col1" >17.43</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row3_col2" class="data row3 col2" >1026.22</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row3_col3" class="data row3 col3" >32.03</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row4_col0" class="data row4 col0" >0.57</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row4_col1" class="data row4 col1" >17.03</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row4_col2" class="data row4 col2" >1000.33</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row4_col3" class="data row4 col3" >31.63</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col0" class="data row5 col0" >0.59</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col1" class="data row5 col1" >17.34</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col2" class="data row5 col2" >962.86</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row5_col3" class="data row5 col3" >31.03</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row6" class="row_heading level0 row6" >SPINE X</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col0" class="data row6 col0" >0.45</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col1" class="data row6 col1" >20.68</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col2" class="data row6 col2" >1409.31</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row6_col3" class="data row6 col3" >37.54</td>
#     </tr>    <tr>
#         <th id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3level0_row7" class="row_heading level0 row7" >ANGLOR</th>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row7_col0" class="data row7 col0" >0.45</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row7_col1" class="data row7 col1" >19.57</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row7_col2" class="data row7 col2" >1246.15</td>
#         <td id="T_d42babfa_9fdd_11e9_b64a_a45e60b969a3row7_col3" class="data row7 col3" >35.3</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(phi_cont, "Phi angle", "Density", filename='phi_cont')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# <h1>Psi angles</h2>

# %% [markdown]
# <h2>Psi angles continuous</h2>

# %%
psi_cont = pd.read_sql_query(f"select * from mllib_features_continuous_PsiAngles join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
psi_cont.groupby("experiment").describe()
# Out:
#                                resi                                            \
#                               count        mean         std  min   25%    50%
# experiment
# anglor_psi                   9119.0  204.450707  155.431013  0.0  76.0  174.0
# blending_psi_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0  174.0
# cnn_domain_angles_IND_TEST   9119.0  204.450707  155.431013  0.0  76.0  174.0
# dcnn_domain_angles_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# lstm_domain_angles_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# observed                     9119.0  204.450707  155.431013  0.0  76.0  174.0
# rf_psi_IND_TEST              9119.0  204.450707  155.431013  0.0  76.0  174.0
# spinex_psi                   9119.0  204.450707  155.431013  0.0  76.0  174.0
# xgb_psi_IND_TEST             9119.0  204.450707  155.431013  0.0  76.0  174.0
#
#                                             val_0                       \
#                                75%    max   count      mean        std
# experiment
# anglor_psi                   303.0  746.0  9119.0  1.732613  52.462271
# blending_psi_IND_TEST        303.0  746.0  9119.0 -5.174865  49.187134
# cnn_domain_angles_IND_TEST   303.0  746.0  9119.0 -7.525400  53.886089
# dcnn_domain_angles_IND_TEST  303.0  746.0  9119.0 -9.719050  51.637047
# lstm_domain_angles_IND_TEST  303.0  746.0  9119.0 -9.500979  53.261054
# observed                     303.0  746.0  9119.0 -6.383672  71.316589
# rf_psi_IND_TEST              303.0  746.0  9119.0 -3.469718  34.376076
# spinex_psi                   303.0  746.0  9119.0  4.396940  75.464249
# xgb_psi_IND_TEST             303.0  746.0  9119.0 -3.933983  41.324190
#
#                                                                           \
#                                     min        25%        50%        75%
# experiment
# anglor_psi                  -172.800000 -36.350000 -18.800000  34.700000
# blending_psi_IND_TEST        -51.645657 -39.807236 -29.395803  12.737933
# cnn_domain_angles_IND_TEST   -54.160210 -41.755212 -37.043723   6.137263
# dcnn_domain_angles_IND_TEST  -47.691190 -42.093126 -38.085925   3.741819
# lstm_domain_angles_IND_TEST  -46.988074 -42.159646 -38.396574  -0.502664
# observed                    -179.965751 -45.996426 -37.053890  -3.045927
# rf_psi_IND_TEST              -47.754051 -32.830551 -12.756498  19.694431
# spinex_psi                  -180.000000 -40.000000 -34.000000  -0.900000
# xgb_psi_IND_TEST             -60.828820 -37.698635 -18.629890  20.840455
#
#
#                                     max
# experiment
# anglor_psi                   180.000000
# blending_psi_IND_TEST        164.881778
# cnn_domain_angles_IND_TEST   167.571751
# dcnn_domain_angles_IND_TEST  168.607568
# lstm_domain_angles_IND_TEST  154.892554
# observed                     179.991139
# rf_psi_IND_TEST              121.296523
# spinex_psi                   179.900000
# xgb_psi_IND_TEST             164.704308

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(psi_cont, filename='psi_cont')
# Out:
# <style  type="text/css" >
#     #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row2_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col3 {
#             : ;
#             background-color:  orange;
#         }</style>
# <table id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row0_col0" class="data row0 col0" >0.62</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row0_col1" class="data row0 col1" >39.5</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row0_col2" class="data row0 col2" >3228.61</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row0_col3" class="data row0 col3" >56.82</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row1_col0" class="data row1 col0" >0.66</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row1_col1" class="data row1 col1" >35.93</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row1_col2" class="data row1 col2" >2893.74</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row1_col3" class="data row1 col3" >53.79</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row2_col0" class="data row2 col0" >0.7</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row2_col1" class="data row2 col1" >28.75</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row2_col2" class="data row2 col2" >2648.83</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row2_col3" class="data row2 col3" >51.47</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row3_col0" class="data row3 col0" >0.68</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row3_col1" class="data row3 col1" >29.47</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row3_col2" class="data row3 col2" >2740.61</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row3_col3" class="data row3 col3" >52.35</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row4_col0" class="data row4 col0" >0.68</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row4_col1" class="data row4 col1" >28.81</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row4_col2" class="data row4 col2" >2762.24</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row4_col3" class="data row4 col3" >52.56</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col0" class="data row5 col0" >0.7</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col1" class="data row5 col1" >30.41</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col2" class="data row5 col2" >2573.11</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row5_col3" class="data row5 col3" >50.73</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row6" class="row_heading level0 row6" >SPINE X</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col0" class="data row6 col0" >0.46</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col1" class="data row6 col1" >41.77</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col2" class="data row6 col2" >5991.92</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row6_col3" class="data row6 col3" >77.41</td>
#     </tr>    <tr>
#         <th id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3level0_row7" class="row_heading level0 row7" >ANGLOR</th>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row7_col0" class="data row7 col0" >0.61</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row7_col1" class="data row7 col1" >38.33</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row7_col2" class="data row7 col2" >3350.11</td>
#         <td id="T_d5049e38_9fdd_11e9_a738_a45e60b969a3row7_col3" class="data row7 col3" >57.88</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(psi_cont, "Psi angle", "Density", filename='psi_cont')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#sns.kdeplot(phi_cont[phi_cont.experiment == 'observed'].val_0.values, psi_cont[psi_cont.experiment == 'observed'].val_0.values)

# %% [markdown]
# # Secondary structure

# %%
sec_cat = pd.read_sql_query(f"select * from mllib_features_categorical_SecStruc join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
sec_cat.groupby("experiment").describe()
# Out:
#                          resi                                            \
#                         count        mean         std  min   25%    50%
# experiment
# blending_sec_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# cnn_sec_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0  174.0
# dcnn_sec_IND_TEST      9119.0  204.450707  155.431013  0.0  76.0  174.0
# lstm_sec_IND_TEST      9119.0  204.450707  155.431013  0.0  76.0  174.0
# observed               9119.0  204.450707  155.431013  0.0  76.0  174.0
# rf_sec_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0  174.0
# spinex_sec             9119.0  204.450707  155.431013  0.0  76.0  174.0
# xgb_sec_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0  174.0
#
#                                       val_0              ...        val_1  \
#                          75%    max   count      mean    ...          75%
# experiment                                               ...
# blending_sec_IND_TEST  303.0  746.0  9119.0  0.668317    ...     0.042877
# cnn_sec_IND_TEST       303.0  746.0  9119.0  0.651559    ...     0.030575
# dcnn_sec_IND_TEST      303.0  746.0  9119.0  0.673473    ...     0.022973
# lstm_sec_IND_TEST      303.0  746.0  9119.0  0.657259    ...     0.022019
# observed               303.0  746.0  9119.0  0.680009    ...     0.000000
# rf_sec_IND_TEST        303.0  746.0  9119.0  0.645460    ...     0.088144
# spinex_sec             303.0  746.0  9119.0  0.614692    ...     0.051850
# xgb_sec_IND_TEST       303.0  746.0  9119.0  0.672780    ...     0.022879
#
#                                   val_2                                \
#                             max   count      mean       std       min
# experiment
# blending_sec_IND_TEST  0.952120  9119.0  0.271396  0.316488  0.026963
# cnn_sec_IND_TEST       0.997830  9119.0  0.287780  0.324639  0.000514
# dcnn_sec_IND_TEST      0.992417  9119.0  0.270689  0.320134  0.000567
# lstm_sec_IND_TEST      0.993746  9119.0  0.291282  0.318557  0.002505
# observed               1.000000  9119.0  0.267464  0.442660  0.000000
# rf_sec_IND_TEST        0.679949  9119.0  0.287044  0.242593  0.000000
# spinex_sec             0.935300  9119.0  0.283324  0.327221  0.023400
# xgb_sec_IND_TEST       0.994888  9119.0  0.286163  0.337648  0.000566
#
#
#                             25%       50%       75%       max
# experiment
# blending_sec_IND_TEST  0.033049  0.065313  0.554012  0.894887
# cnn_sec_IND_TEST       0.018253  0.106301  0.572399  0.996158
# dcnn_sec_IND_TEST      0.014174  0.085564  0.527231  0.991386
# lstm_sec_IND_TEST      0.020831  0.122463  0.565318  0.985250
# observed               0.000000  0.000000  1.000000  1.000000
# rf_sec_IND_TEST        0.071976  0.214968  0.477516  0.952435
# spinex_sec             0.032500  0.078300  0.572450  0.936400
# xgb_sec_IND_TEST       0.013186  0.082676  0.589869  0.994251
#
# [8 rows x 32 columns]

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cat(sec_cat, 3, class_names=['H', 'E', 'C'], filename='sec_cat')
# Out:
# <style  type="text/css" >
#     #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col6 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col7 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col8 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col9 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col12 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col13 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row2_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row3_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row3_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row3_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row3_col11 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col12 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col13 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row4_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col8 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col10 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col11 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row5_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col5 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col6 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col10 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col11 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col12 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col13 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col14 {
#             background-color:  yellow;
#             : ;
#         }    #T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row6_col15 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ACC</th>
#         <th class="col_heading level0 col1" >H (P)</th>
#         <th class="col_heading level0 col2" >H (R)</th>
#         <th class="col_heading level0 col3" >H (F1)</th>
#         <th class="col_heading level0 col4" >H (AUC)</th>
#         <th class="col_heading level0 col5" >H (MCC)</th>
#         <th class="col_heading level0 col6" >E (P)</th>
#         <th class="col_heading level0 col7" >E (R)</th>
#         <th class="col_heading level0 col8" >E (F1)</th>
#         <th class="col_heading level0 col9" >E (AUC)</th>
#         <th class="col_heading level0 col10" >E (MCC)</th>
#         <th class="col_heading level0 col11" >C (P)</th>
#         <th class="col_heading level0 col12" >C (R)</th>
#         <th class="col_heading level0 col13" >C (F1)</th>
#         <th class="col_heading level0 col14" >C (AUC)</th>
#         <th class="col_heading level0 col15" >C (MCC)</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col0" class="data row0 col0" >0.82</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col1" class="data row0 col1" >0.86</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col2" class="data row0 col2" >0.9</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col3" class="data row0 col3" >0.88</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col4" class="data row0 col4" >0.8</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col5" class="data row0 col5" >0.62</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col6" class="data row0 col6" >0.97</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col7" class="data row0 col7" >0.23</td>
#         <td id="T_d63405dc_9fdd_11e9_b3c8_a45e60b969a3row0_col8" class="data row0 col8" >0.37</td>
#         <td id="T_d63405dc_9

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
 plots_cat(sec_cat, {"cat": sec_cat}, filename='sec_cat', class_names=['H', 'E', 'C'])

# %% [markdown]
# # Secondary structure WITHOUT TMS

# %%
sec_cat_notms = pd.read_sql_query(f"select p.experiment, p.resi, p.val_0, p.val_1, p.val_2 from mllib_features_categorical_SecStruc as p join raw_data using (id, resi) join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where topo!='T' and topo !='R' and experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
sec_cat_notms.groupby("experiment").describe()
# Out:
#                          resi                                            \
#                         count        mean         std  min   25%    50%
# experiment
# blending_sec_IND_TEST  4929.0  230.624873  165.915039  0.0  95.0  205.0
# cnn_sec_IND_TEST       4929.0  230.624873  165.915039  0.0  95.0  205.0
# dcnn_sec_IND_TEST      4929.0  230.624873  165.915039  0.0  95.0  205.0
# lstm_sec_IND_TEST      4929.0  230.624873  165.915039  0.0  95.0  205.0
# observed               4929.0  230.624873  165.915039  0.0  95.0  205.0
# rf_sec_IND_TEST        4929.0  230.624873  165.915039  0.0  95.0  205.0
# spinex_sec             4929.0  230.624873  165.915039  0.0  95.0  205.0
# xgb_sec_IND_TEST       4929.0  230.624873  165.915039  0.0  95.0  205.0
#
#                                       val_0              ...        val_1  \
#                          75%    max   count      mean    ...          75%
# experiment                                               ...
# blending_sec_IND_TEST  339.0  746.0  4929.0  0.472137    ...     0.068367
# cnn_sec_IND_TEST       339.0  746.0  4929.0  0.447890    ...     0.074705
# dcnn_sec_IND_TEST      339.0  746.0  4929.0  0.476220    ...     0.063671
# lstm_sec_IND_TEST      339.0  746.0  4929.0  0.459475    ...     0.059815
# observed               339.0  746.0  4929.0  0.485494    ...     0.000000
# rf_sec_IND_TEST        339.0  746.0  4929.0  0.480951    ...     0.113451
# spinex_sec             339.0  746.0  4929.0  0.473378    ...     0.074700
# xgb_sec_IND_TEST       339.0  746.0  4929.0  0.473158    ...     0.043520
#
#                                   val_2                                \
#                             max   count      mean       std       min
# experiment
# blending_sec_IND_TEST  0.952120  4929.0  0.423290  0.332893  0.028000
# cnn_sec_IND_TEST       0.997830  4929.0  0.446739  0.331846  0.000735
# dcnn_sec_IND_TEST      0.992417  4929.0  0.424376  0.331527  0.001109
# lstm_sec_IND_TEST      0.993746  4929.0  0.448988  0.321495  0.003060
# observed               1.000000  4929.0  0.420978  0.493766  0.000000
# rf_sec_IND_TEST        0.679949  4929.0  0.422877  0.224568  0.013555
# spinex_sec             0.929800  4929.0  0.407648  0.349655  0.026000
# xgb_sec_IND_TEST       0.994888  4929.0  0.456886  0.344348  0.000999
#
#
#                             25%       50%       75%       max
# experiment
# blending_sec_IND_TEST  0.069543  0.382660  0.783719  0.894887
# cnn_sec_IND_TEST       0.098885  0.443066  0.766339  0.996158
# dcnn_sec_IND_TEST      0.082395  0.400360  0.752534  0.991386
# lstm_sec_IND_TEST      0.116624  0.451733  0.756474  0.985250
# observed               0.000000  0.000000  1.000000  1.000000
# rf_sec_IND_TEST        0.228633  0.418415  0.604634  0.952435
# spinex_sec             0.053600  0.293100  0.807400  0.936400
# xgb_sec_IND_TEST       0.090541  0.452124  0.798347  0.994251
#
# [8 rows x 32 columns]

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cat(sec_cat_notms, 3, class_names=['H', 'E', 'C'], filename='sec_cat_notms')
# Out:
# <style  type="text/css" >
#     #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col5 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col6 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col7 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col8 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col9 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col11 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col8 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col10 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col12 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col13 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row2_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row3_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row3_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row4_col13 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row4_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row4_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col4 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col5 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col7 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col8 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col9 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col10 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col11 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col13 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col14 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row5_col15 {
#             : ;
#             background-color:  orange;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col6 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col10 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col12 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col13 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col14 {
#             background-color:  yellow;
#             : ;
#         }    #T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row6_col15 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ACC</th>
#         <th class="col_heading level0 col1" >H (P)</th>
#         <th class="col_heading level0 col2" >H (R)</th>
#         <th class="col_heading level0 col3" >H (F1)</th>
#         <th class="col_heading level0 col4" >H (AUC)</th>
#         <th class="col_heading level0 col5" >H (MCC)</th>
#         <th class="col_heading level0 col6" >E (P)</th>
#         <th class="col_heading level0 col7" >E (R)</th>
#         <th class="col_heading level0 col8" >E (F1)</th>
#         <th class="col_heading level0 col9" >E (AUC)</th>
#         <th class="col_heading level0 col10" >E (MCC)</th>
#         <th class="col_heading level0 col11" >C (P)</th>
#         <th class="col_heading level0 col12" >C (R)</th>
#         <th class="col_heading level0 col13" >C (F1)</th>
#         <th class="col_heading level0 col14" >C (AUC)</th>
#         <th class="col_heading level0 col15" >C (MCC)</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col0" class="data row0 col0" >0.73</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col1" class="data row0 col1" >0.74</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col2" class="data row0 col2" >0.78</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col3" class="data row0 col3" >0.76</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col4" class="data row0 col4" >0.76</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col5" class="data row0 col5" >0.52</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col6" class="data row0 col6" >0.97</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col7" class="data row0 col7" >0.24</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col8" class="data row0 col8" >0.39</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col9" class="data row0 col9" >0.62</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col10" class="data row0 col10" >0.47</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col11" class="data row0 col11" >0.7</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col12" class="data row0 col12" >0.78</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col13" class="data row0 col13" >0.74</td>
#         <td id="T_d8236b76_9fdd_11e9_96bf_a45e60b969a3row0_col14" class="data row0 col14" >0.77</td>
#         <td

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
 plots_cat(sec_cat_notms, {"cat": sec_cat_notms}, filename='sec_cat_notms', class_names=['H', 'E', 'C'])

# %% [markdown]
# # RSA

# %% [markdown]
# <h2>RSA complex</h2>

# %%
rsa_comp_cont = pd.read_sql_query(f"select * from mllib_features_continuous_RsaComplex join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
rsa_comp_cont.groupby("experiment").describe()
# Out:
#                                  resi                                     \
#                                 count        mean         std  min   25%
# experiment
# blending_rsa_complex_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0
# cnn_domain_rsa_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0
# dcnn_domain_rsa_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0
# lstm_domain_rsa_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0
# observed                       9119.0  204.450707  155.431013  0.0  76.0
# rf_rsa_complex_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0
# spinex_rsa                     9119.0  204.450707  155.431013  0.0  76.0
# xgb_rsa_complex_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0
#
#                                                      val_0            \
#                                  50%    75%    max   count      mean
# experiment
# blending_rsa_complex_IND_TEST  174.0  303.0  746.0  9119.0  0.265246
# cnn_domain_rsa_IND_TEST        174.0  303.0  746.0  9119.0  0.240040
# dcnn_domain_rsa_IND_TEST       174.0  303.0  746.0  9119.0  0.246077
# lstm_domain_rsa_IND_TEST       174.0  303.0  746.0  9119.0  0.238227
# observed                       174.0  303.0  746.0  9119.0  0.251038
# rf_rsa_complex_IND_TEST        174.0  303.0  746.0  9119.0  0.270309
# spinex_rsa                     174.0  303.0  746.0  9119.0  0.202402
# xgb_rsa_complex_IND_TEST       174.0  303.0  746.0  9119.0  0.265800
#
#                                                                        \
#                                     std       min       25%       50%
# experiment
# blending_rsa_complex_IND_TEST  0.169433 -0.006684  0.115006  0.240473
# cnn_domain_rsa_IND_TEST        0.183721  0.000603  0.071533  0.211000
# dcnn_domain_rsa_IND_TEST       0.182199 -0.010676  0.081785  0.217915
# lstm_domain_rsa_IND_TEST       0.180527 -0.035773  0.075860  0.208411
# observed                       0.246289  0.000000  0.030488  0.176471
# rf_rsa_complex_IND_TEST        0.128175  0.019999  0.162551  0.255215
# spinex_rsa                     0.137878  0.009434  0.098780  0.163208
# xgb_rsa_complex_IND_TEST       0.147661 -0.047219  0.141105  0.248572
#
#
#                                     75%       max
# experiment
# blending_rsa_complex_IND_TEST  0.397891  0.887808
# cnn_domain_rsa_IND_TEST        0.381867  1.031382
# dcnn_domain_rsa_IND_TEST       0.386195  1.004587
# lstm_domain_rsa_IND_TEST       0.377645  0.981666
# observed                       0.419118  1.000000
# rf_rsa_complex_IND_TEST        0.372943  0.666718
# spinex_rsa                     0.277370  0.780986
# xgb_rsa_complex_IND_TEST       0.381779  0.735714

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(rsa_comp_cont, filename='rsa_comp_cont')
# Out:
# <style  type="text/css" >
#     #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row1_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row2_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row3_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row4_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col3 {
#             : ;
#             background-color:  orange;
#         }</style>
# <table id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row0_col0" class="data row0 col0" >0.59</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row0_col1" class="data row0 col1" >0.16</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row0_col2" class="data row0 col2" >0.04</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row0_col3" class="data row0 col3" >0.2</td>
#     </tr>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row1_col0" class="data row1 col0" >0.63</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row1_col1" class="data row1 col1" >0.15</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row1_col2" class="data row1 col2" >0.04</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row1_col3" class="data row1 col3" >0.19</td>
#     </tr>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row2_col0" class="data row2 col0" >0.63</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row2_col1" class="data row2 col1" >0.14</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row2_col2" class="data row2 col2" >0.04</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row2_col3" class="data row2 col3" >0.19</td>
#     </tr>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row3_col0" class="data row3 col0" >0.64</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row3_col1" class="data row3 col1" >0.14</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row3_col2" class="data row3 col2" >0.04</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row3_col3" class="data row3 col3" >0.19</td>
#     </tr>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row4_col0" class="data row4 col0" >0.65</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row4_col1" class="data row4 col1" >0.14</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row4_col2" class="data row4 col2" >0.04</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row4_col3" class="data row4 col3" >0.19</td>
#     </tr>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col0" class="data row5 col0" >0.66</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col1" class="data row5 col1" >0.14</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col2" class="data row5 col2" >0.03</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row5_col3" class="data row5 col3" >0.19</td>
#     </tr>    <tr>
#         <th id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3level0_row6" class="row_heading level0 row6" >SPINE X</th>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col0" class="data row6 col0" >0.5</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col1" class="data row6 col1" >0.17</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col2" class="data row6 col2" >0.05</td>
#         <td id="T_d9a7ff66_9fdd_11e9_92cd_a45e60b969a3row6_col3" class="data row6 col3" >0.22</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(rsa_comp_cont, "RSA complex", "Density", filename='rsa_comp_cont')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # RSA chain

# %%
rsa_chain_cont = pd.read_sql_query(f"select * from mllib_features_continuous_RsaChain join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
rsa_chain_cont.groupby("experiment").describe()
# Out:
#                                resi                                            \
#                               count        mean         std  min   25%    50%
# experiment
# blending_rsa_chain_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# cnn_domain_rsa_IND_TEST      9119.0  204.450707  155.431013  0.0  76.0  174.0
# dcnn_domain_rsa_IND_TEST     9119.0  204.450707  155.431013  0.0  76.0  174.0
# lstm_domain_rsa_IND_TEST     9119.0  204.450707  155.431013  0.0  76.0  174.0
# observed                     9119.0  204.450707  155.431013  0.0  76.0  174.0
# rf_rsa_chain_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0  174.0
# spinex_rsa                   9119.0  204.450707  155.431013  0.0  76.0  174.0
# xgb_rsa_chain_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0  174.0
#
#                                             val_0                      \
#                                75%    max   count      mean       std
# experiment
# blending_rsa_chain_IND_TEST  303.0  746.0  9119.0  0.307951  0.174745
# cnn_domain_rsa_IND_TEST      303.0  746.0  9119.0  0.281208  0.192392
# dcnn_domain_rsa_IND_TEST     303.0  746.0  9119.0  0.287832  0.191078
# lstm_domain_rsa_IND_TEST     303.0  746.0  9119.0  0.281632  0.189134
# observed                     303.0  746.0  9119.0  0.323908  0.264468
# rf_rsa_chain_IND_TEST        303.0  746.0  9119.0  0.318431  0.121970
# spinex_rsa                   303.0  746.0  9119.0  0.202402  0.137878
# xgb_rsa_chain_IND_TEST       303.0  746.0  9119.0  0.314831  0.149507
#
#
#                                   min       25%       50%       75%       max
# experiment
# blending_rsa_chain_IND_TEST -0.022577  0.158858  0.299981  0.445264  0.929711
# cnn_domain_rsa_IND_TEST     -0.005108  0.105571  0.267743  0.433204  1.082910
# dcnn_domain_rsa_IND_TEST    -0.013665  0.117261  0.275516  0.435194  1.087819
# lstm_domain_rsa_IND_TEST    -0.042356  0.114263  0.267657  0.427261  1.001609
# observed                     0.000000  0.072165  0.294416  0.524390  1.000000
# rf_rsa_chain_IND_TEST        0.029666  0.222401  0.315449  0.414092  0.684437
# spinex_rsa                   0.009434  0.098780  0.163208  0.277370  0.780986
# xgb_rsa_chain_IND_TEST      -0.037285  0.195994  0.311381  0.431261  0.824328

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(rsa_chain_cont, filename='rsa_chain_cont')
# Out:
# <style  type="text/css" >
#     #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row1_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row3_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row4_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col3 {
#             : ;
#             background-color:  orange;
#         }</style>
# <table id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row0_col0" class="data row0 col0" >0.57</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row0_col1" class="data row0 col1" >0.18</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row0_col2" class="data row0 col2" >0.05</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row0_col3" class="data row0 col3" >0.22</td>
#     </tr>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row1_col0" class="data row1 col0" >0.63</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row1_col1" class="data row1 col1" >0.17</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row1_col2" class="data row1 col2" >0.04</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row1_col3" class="data row1 col3" >0.21</td>
#     </tr>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row2_col0" class="data row2 col0" >0.61</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row2_col1" class="data row2 col1" >0.16</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row2_col2" class="data row2 col2" >0.05</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row2_col3" class="data row2 col3" >0.22</td>
#     </tr>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row3_col0" class="data row3 col0" >0.65</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row3_col1" class="data row3 col1" >0.16</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row3_col2" class="data row3 col2" >0.04</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row3_col3" class="data row3 col3" >0.21</td>
#     </tr>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row4_col0" class="data row4 col0" >0.64</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row4_col1" class="data row4 col1" >0.16</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row4_col2" class="data row4 col2" >0.04</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row4_col3" class="data row4 col3" >0.21</td>
#     </tr>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col0" class="data row5 col0" >0.67</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col1" class="data row5 col1" >0.15</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col2" class="data row5 col2" >0.04</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row5_col3" class="data row5 col3" >0.2</td>
#     </tr>    <tr>
#         <th id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3level0_row6" class="row_heading level0 row6" >SPINE X</th>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col0" class="data row6 col0" >0.46</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col1" class="data row6 col1" >0.2</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col2" class="data row6 col2" >0.07</td>
#         <td id="T_da76d534_9fdd_11e9_9f26_a45e60b969a3row6_col3" class="data row6 col3" >0.26</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(rsa_chain_cont, "RSA monomer", "Density", filename='rsa_chain_cont')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # RSA diff

# %%
rsa_diff_cont = pd.read_sql_query(f"select * from mllib_features_continuous_RsaDiff join (select distinct id from datasets where name='{dataset_name}' and kind='{kind}') a using (id) where experiment not like '%_VALID_%' and experiment not like '%_IND_TEST_%' order by experiment, id, resi", conn)

# %% [markdown]
# <h3>Data description</h3>

# %%
rsa_diff_cont.groupby("experiment").describe()
# Out:
#                               resi                                            \
#                              count        mean         std  min   25%    50%
# experiment
# blending_rsa_diff_IND_TEST  9119.0  204.450707  155.431013  0.0  76.0  174.0
# cnn_domain_rsa_IND_TEST     9119.0  204.450707  155.431013  0.0  76.0  174.0
# dcnn_domain_rsa_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0  174.0
# lstm_domain_rsa_IND_TEST    9119.0  204.450707  155.431013  0.0  76.0  174.0
# observed                    9119.0  204.450707  155.431013  0.0  76.0  174.0
# rf_rsa_diff_IND_TEST        9119.0  204.450707  155.431013  0.0  76.0  174.0
# xgb_rsa_diff_IND_TEST       9119.0  204.450707  155.431013  0.0  76.0  174.0
#
#                                            val_0                      \
#                               75%    max   count      mean       std
# experiment
# blending_rsa_diff_IND_TEST  303.0  746.0  9119.0  0.044508  0.040946
# cnn_domain_rsa_IND_TEST     303.0  746.0  9119.0  0.000651  0.001626
# dcnn_domain_rsa_IND_TEST    303.0  746.0  9119.0  0.003513  0.007621
# lstm_domain_rsa_IND_TEST    303.0  746.0  9119.0  0.003007  0.008247
# observed                    303.0  746.0  9119.0  0.072869  0.155712
# rf_rsa_diff_IND_TEST        303.0  746.0  9119.0  0.053515  0.032748
# xgb_rsa_diff_IND_TEST       303.0  746.0  9119.0  0.051913  0.035666
#
#
#                                  min       25%       50%       75%       max
# experiment
# blending_rsa_diff_IND_TEST -0.021446  0.017308  0.032522  0.057946  0.434442
# cnn_domain_rsa_IND_TEST    -0.032009 -0.000309  0.000473  0.001388  0.030256
# dcnn_domain_rsa_IND_TEST   -0.012343 -0.000625  0.001870  0.004934  0.061310
# lstm_domain_rsa_IND_TEST   -0.005446  0.000216  0.000949  0.002167  0.119121
# observed                    0.000000  0.000000  0.000000  0.026102  1.000000
# rf_rsa_diff_IND_TEST        0.003355  0.028270  0.046784  0.072085  0.217334
# xgb_rsa_diff_IND_TEST      -0.001630  0.027893  0.042130  0.064586  0.357934

# %% [markdown]
# <h3>Benchmark measures</h3>

# %%
measures_cont(rsa_diff_cont, filename='rsa_diff_cont')
# Out:
# <style  type="text/css" >
#     #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col1 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col2 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col3 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col0 {
#             : ;
#             background-color:  orange;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col3 {
#             background-color:  yellow;
#             : ;
#         }</style>
# <table id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >MAE</th>
#         <th class="col_heading level0 col2" >MSE</th>
#         <th class="col_heading level0 col3" >RMSE</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3level0_row0" class="row_heading level0 row0" >RF</th>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col0" class="data row0 col0" >0.32</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col1" class="data row0 col1" >0.09</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col2" class="data row0 col2" >0.02</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row0_col3" class="data row0 col3" >0.15</td>
#     </tr>    <tr>
#         <th id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3level0_row1" class="row_heading level0 row1" >GBM</th>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col0" class="data row1 col0" >0.33</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col1" class="data row1 col1" >0.09</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col2" class="data row1 col2" >0.02</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row1_col3" class="data row1 col3" >0.15</td>
#     </tr>    <tr>
#         <th id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3level0_row2" class="row_heading level0 row2" >conv</th>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col0" class="data row2 col0" >0.16</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col1" class="data row2 col1" >0.07</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col2" class="data row2 col2" >0.03</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row2_col3" class="data row2 col3" >0.17</td>
#     </tr>    <tr>
#         <th id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3level0_row3" class="row_heading level0 row3" >dconv</th>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col0" class="data row3 col0" >0.33</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col1" class="data row3 col1" >0.07</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col2" class="data row3 col2" >0.03</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row3_col3" class="data row3 col3" >0.17</td>
#     </tr>    <tr>
#         <th id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3level0_row4" class="row_heading level0 row4" >LSTM</th>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col0" class="data row4 col0" >0.22</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col1" class="data row4 col1" >0.07</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col2" class="data row4 col2" >0.03</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row4_col3" class="data row4 col3" >0.17</td>
#     </tr>    <tr>
#         <th id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3level0_row5" class="row_heading level0 row5" >AllesTM</th>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col0" class="data row5 col0" >0.39</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col1" class="data row5 col1" >0.08</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col2" class="data row5 col2" >0.02</td>
#         <td id="T_db3c927e_9fdd_11e9_9c0a_a45e60b969a3row5_col3" class="data row5 col3" >0.15</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# <h3>Benchmark plots</h3>

# %%
plots_cont(rsa_diff_cont, "RSA change", "Density", filename='rsa_diff_cont')
# Out:
# /Users/peter/miniconda3/envs/jupyter/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Others

# %%
history = json.loads(conn.cursor().execute('select history from experiments where experiment="keras_all_targets" and fold=0').fetchone()[0])
history.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-91d1fc6c3dd8> in <module>()
# ----> 1 history = json.loads(conn.cursor().execute('select history from experiments where experiment="keras_all_targets" and fold=0').fetchone()[0])
#       2 history.keys()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.plot(range(len(history['loss'])), history['loss'])
plt.plot(range(len(history['val_loss'])), history['val_loss'])
plt.plot(range(len(history['lr'])), np.log(history['lr']) - np.min(np.log(history['lr'])))

# %%
import sys
sys.path.append('..')

# %%
from mllib.features.continuous import Pssm, Pssm2
from mllib.retrievers import SQLRetriever

# %%
vals = []
vals2 = []
for idx in conn.cursor().execute('select id from alignments limit 20'):
    print(idx)
    #vals.extend(Pssm().transform(SQLRetriever(conn, Pssm.query).transform(idx[0])).flatten())
    #vals2.extend(Pssm2().transform(SQLRetriever(conn, Pssm.query).transform(idx[0])).flatten())
    
#msa = SQLRetriever(conn, Pssm.query).transform('1kpl_B')
#%time Pssm().transform(msa)

# %%
len(vals), len(vals2)

# %%
vals = np.array(vals)
vals2 = np.array(vals2)

# %%
def normalize(xs):
    return list(map(lambda x: 1 / (1 + np.exp(-1 * x)), xs))
                
hist = True
kde = False
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sns.distplot(vals / 2 + 0.5, label='pssm', hist=hist, kde=kde, ax=axs[0])
sns.distplot(vals2, label='pssm2', hist=hist, kde=kde, ax=axs[1])
plt.legend()

# %%
xxx = pd.read_sql_query('select phi, psi from raw_data', conn)

# %%
xxx.describe()

# %%
print(math.pi)
